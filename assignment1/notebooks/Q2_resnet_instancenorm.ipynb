# %%
import torch
from resnet_instance_norm import ResNet
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
from torchvision.transforms import ToTensor
import torch.optim as optim
import torch.nn as nn

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
def resnet_6n_2(n, r):
    """
    This creates a ResNet model with 5 residual blocks 
    in each of the three sets of hidden layers, 
    and a fully connected output layer with 10 units.
    """
    return ResNet(n, r)

# %%
model = resnet_6n_2(2, 10).to(device)

# %%
model
# Out:
# ResNet(
#   (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): MyInstanceNorm()
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): MyInstanceNorm()
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): MyInstanceNorm()
#       (shortcut): Sequential()
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): MyInstanceNorm()
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): MyInstanceNorm()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): MyInstanceNorm()
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): MyInstanceNorm()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): MyInstanceNorm()
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): MyInstanceNorm()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): MyInstanceNorm()
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): MyInstanceNorm()
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): MyInstanceNorm()
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): MyInstanceNorm()
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#   (fc): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
data_path = "../data"

# %%
batch_size = 128
# Load CIFAR10 dataset
train_dataset = datasets.CIFAR10(root=data_path, train=True, transform=ToTensor(), download=True)
val_dataset = torch.utils.data.Subset(train_dataset, torch.randint(high=len(train_dataset), size=(10000,)))
train_dataset = torch.utils.data.Subset(train_dataset, torch.arange(len(train_dataset))[~val_dataset.indices])
test_dataset = datasets.CIFAR10(root=data_path, train=False, transform=ToTensor())

# Define data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Files already downloaded and verified

# %%
# Define optimizer and loss function
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50, 75], gamma=0.1)
criterion = nn.CrossEntropyLoss()

# %%
# Define lists for storing accuracy and loss values for train, val and test data
train_losses, train_accs, train_micro_f1s, train_macro_f1s = [], [], [], []
val_losses, val_accs, val_micro_f1s, val_macro_f1s = [], [], [], []
test_losses, test_accs, test_micro_f1s, test_macro_f1s = [], [], [], []

# %%
num_epochs = 100
early_stop_patience = 10
best_val_loss = float('inf')

# %%
import sklearn
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report

# %%
# Train the model
for epoch in range(num_epochs):
    # Train the model on the train set
    model.train()
    train_loss = 0.0
    train_preds, train_targets = [], []
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data.size(0)
        train_preds += output.argmax(dim=1).tolist()
        train_targets += target.tolist()
    train_loss /= len(train_dataset)
    train_acc = accuracy_score(train_targets, train_preds)
    train_micro_f1 = f1_score(train_targets, train_preds, average='micro')
    train_macro_f1 = f1_score(train_targets, train_preds, average='macro')
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    train_micro_f1s.append(train_micro_f1)
    train_macro_f1s.append(train_macro_f1)
    print('Epoch {}, Train Loss: {:.2f}, Train Acc: {:.2f}, Train Micro F1: {:.2f}, Train Macro F1: {:.2f}'.format(
        epoch+1, train_loss, train_acc, train_micro_f1, train_macro_f1
    ))
    
    # Evaluate the model on the validation set
    model.eval()
    val_loss = 0.0
    val_preds, val_targets = [], []
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(val_loader):
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            val_loss += loss.item() * data.size(0)
            val_preds += output.argmax(dim=1).tolist()
            val_targets += target.tolist()
    val_loss /= len(val_dataset)
    val_acc = accuracy_score(val_targets, val_preds)
    val_micro_f1 = f1_score(val_targets, val_preds, average='micro')
    val_macro_f1 = f1_score(val_targets, val_preds, average='macro')
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    val_micro_f1s.append(val_micro_f1)
    val_macro_f1s.append(val_macro_f1)
    print('Epoch {}, Val Loss: {:.2f}, Val Acc: {:.2f}, Val Micro F1: {:.2f}, Val Macro F1: {:.2f}'.format(
        epoch+1, val_loss, val_acc, val_micro_f1, val_macro_f1
    ))

    # Evaluate the model on the test set
    model.eval()
    test_loss = 0.0
    test_preds, test_targets = [], []
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item() * data.size(0)
            test_preds += output.argmax(dim=1).tolist()
            test_targets += target.tolist()
    test_loss /= len(test_dataset)
    test_acc = accuracy_score(test_targets, test_preds)
    test_micro_f1 = f1_score(test_targets, test_preds, average='micro')
    test_macro_f1 = f1_score(test_targets, test_preds, average='macro')
    test_losses.append(test_loss)
    test_accs.append(test_acc)
    test_micro_f1s.append(test_micro_f1)
    test_macro_f1s.append(test_macro_f1)
    print('Test Loss: {:.2f}, Test Acc: {:.2f}, Test Micro F1: {:.2f}, Test Macro F1: {:.2f}'.format(
        test_loss, test_acc, test_micro_f1, test_macro_f1
    ))
    
    # Save the model if the validation loss is the best we've seen so far
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), './model_best.pth')
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        if early_stop_counter == early_stop_patience:
            print('Early stopping!')
            break
# Out:
# Epoch 1, Train Loss: 2.05, Train Acc: 0.22, Train Micro F1: 0.22, Train Macro F1: 0.22
# Epoch 1, Val Loss: 1.72, Val Acc: 0.35, Val Micro F1: 0.35, Val Macro F1: 0.30
# Test Loss: 1.72, Test Acc: 0.36, Test Micro F1: 0.36, Test Macro F1: 0.30
# Epoch 2, Train Loss: 1.63, Train Acc: 0.39, Train Micro F1: 0.39, Train Macro F1: 0.39
# Epoch 2, Val Loss: 1.54, Val Acc: 0.42, Val Micro F1: 0.42, Val Macro F1: 0.40
# Test Loss: 1.55, Test Acc: 0.43, Test Micro F1: 0.43, Test Macro F1: 0.41
# Epoch 3, Train Loss: 1.42, Train Acc: 0.47, Train Micro F1: 0.47, Train Macro F1: 0.47
# Epoch 3, Val Loss: 1.80, Val Acc: 0.41, Val Micro F1: 0.41, Val Macro F1: 0.39
# Test Loss: 1.81, Test Acc: 0.41, Test Micro F1: 0.41, Test Macro F1: 0.39
# Epoch 4, Train Loss: 1.33, Train Acc: 0.51, Train Micro F1: 0.51, Train Macro F1: 0.51
# Epoch 4, Val Loss: 1.36, Val Acc: 0.50, Val Micro F1: 0.50, Val Macro F1: 0.50
# Test Loss: 1.38, Test Acc: 0.51, Test Micro F1: 0.51, Test Macro F1: 0.51
# Epoch 5, Train Loss: 1.17, Train Acc: 0.58, Train Micro F1: 0.58, Train Macro F1: 0.57
# Epoch 5, Val Loss: 1.55, Val Acc: 0.46, Val Micro F1: 0.46, Val Macro F1: 0.44
# Test Loss: 1.57, Test Acc: 0.46, Test Micro F1: 0.46, Test Macro F1: 0.44
# Epoch 6, Train Loss: 1.09, Train Acc: 0.61, Train Micro F1: 0.61, Train Macro F1: 0.60
# Epoch 6, Val Loss: 1.26, Val Acc: 0.54, Val Micro F1: 0.54, Val Macro F1: 0.52
# Test Loss: 1.31, Test Acc: 0.53, Test Micro F1: 0.53, Test Macro F1: 0.51
# Epoch 7, Train Loss: 0.98, Train Acc: 0.65, Train Micro F1: 0.65, Train Macro F1: 0.65
# Epoch 7, Val Loss: 1.15, Val Acc: 0.58, Val Micro F1: 0.58, Val Macro F1: 0.56
# Test Loss: 1.20, Test Acc: 0.56, Test Micro F1: 0.56, Test Macro F1: 0.54
# Epoch 8, Train Loss: 0.89, Train Acc: 0.68, Train Micro F1: 0.68, Train Macro F1: 0.68
# Epoch 8, Val Loss: 1.25, Val Acc: 0.56, Val Micro F1: 0.56, Val Macro F1: 0.55
# Test Loss: 1.29, Test Acc: 0.54, Test Micro F1: 0.54, Test Macro F1: 0.54
# Epoch 9, Train Loss: 0.85, Train Acc: 0.69, Train Micro F1: 0.69, Train Macro F1: 0.69
# Epoch 9, Val Loss: 1.18, Val Acc: 0.60, Val Micro F1: 0.60, Val Macro F1: 0.60
# Test Loss: 1.26, Test Acc: 0.57, Test Micro F1: 0.57, Test Macro F1: 0.57
# Epoch 10, Train Loss: 0.79, Train Acc: 0.72, Train Micro F1: 0.72, Train Macro F1: 0.72
# Epoch 10, Val Loss: 1.00, Val Acc: 0.65, Val Micro F1: 0.65, Val Macro F1: 0.65
# Test Loss: 1.08, Test Acc: 0.62, Test Micro F1: 0.62, Test Macro F1: 0.61
# Epoch 11, Train Loss: 0.69, Train Acc: 0.76, Train Micro F1: 0.76, Train Macro F1: 0.76
# Epoch 11, Val Loss: 1.00, Val Acc: 0.66, Val Micro F1: 0.66, Val Macro F1: 0.65
# Test Loss: 1.07, Test Acc: 0.63, Test Micro F1: 0.63, Test Macro F1: 0.62
# Epoch 12, Train Loss: 0.64, Train Acc: 0.78, Train Micro F1: 0.78, Train Macro F1: 0.78
# Epoch 12, Val Loss: 1.03, Val Acc: 0.65, Val Micro F1: 0.65, Val Macro F1: 0.65
# Test Loss: 1.12, Test Acc: 0.62, Test Micro F1: 0.62, Test Macro F1: 0.61
# Epoch 13, Train Loss: 0.58, Train Acc: 0.80, Train Micro F1: 0.80, Train Macro F1: 0.80
# Epoch 13, Val Loss: 1.05, Val Acc: 0.65, Val Micro F1: 0.65, Val Macro F1: 0.65
# Test Loss: 1.14, Test Acc: 0.62, Test Micro F1: 0.62, Test Macro F1: 0.62
# Epoch 14, Train Loss: 0.53, Train Acc: 0.82, Train Micro F1: 0.82, Train Macro F1: 0.82
# Epoch 14, Val Loss: 1.31, Val Acc: 0.58, Val Micro F1: 0.58, Val Macro F1: 0.56
# Test Loss: 1.43, Test Acc: 0.55, Test Micro F1: 0.55, Test Macro F1: 0.53
# Epoch 15, Train Loss: 0.50, Train Acc: 0.83, Train Micro F1: 0.83, Train Macro F1: 0.83
# Epoch 15, Val Loss: 1.33, Val Acc: 0.60, Val Micro F1: 0.60, Val Macro F1: 0.60
# Test Loss: 1.45, Test Acc: 0.57, Test Micro F1: 0.57, Test Macro F1: 0.57
# Epoch 16, Train Loss: 0.42, Train Acc: 0.86, Train Micro F1: 0.86, Train Macro F1: 0.86
# Epoch 16, Val Loss: 1.15, Val Acc: 0.64, Val Micro F1: 0.64, Val Macro F1: 0.63
# Test Loss: 1.30, Test Acc: 0.59, Test Micro F1: 0.59, Test Macro F1: 0.58
# Epoch 17, Train Loss: 0.39, Train Acc: 0.87, Train Micro F1: 0.87, Train Macro F1: 0.87
# Epoch 17, Val Loss: 1.20, Val Acc: 0.64, Val Micro F1: 0.64, Val Macro F1: 0.62
# Test Loss: 1.32, Test Acc: 0.60, Test Micro F1: 0.60, Test Macro F1: 0.58
# Epoch 18, Train Loss: 0.39, Train Acc: 0.87, Train Micro F1: 0.87, Train Macro F1: 0.87
# Epoch 18, Val Loss: 0.98, Val Acc: 0.69, Val Micro F1: 0.69, Val Macro F1: 0.69
# Test Loss: 1.12, Test Acc: 0.65, Test Micro F1: 0.65, Test Macro F1: 0.65
# Epoch 19, Train Loss: 0.34, Train Acc: 0.89, Train Micro F1: 0.89, Train Macro F1: 0.89
# Epoch 19, Val Loss: 0.96, Val Acc: 0.70, Val Micro F1: 0.70, Val Macro F1: 0.70
# Test Loss: 1.11, Test Acc: 0.65, Test Micro F1: 0.65, Test Macro F1: 0.65
# Epoch 20, Train Loss: 0.34, Train Acc: 0.89, Train Micro F1: 0.89, Train Macro F1: 0.89
# Epoch 20, Val Loss: 1.00, Val Acc: 0.70, Val Micro F1: 0.70, Val Macro F1: 0.69
# Test Loss: 1.16, Test Acc: 0.64, Test Micro F1: 0.64, Test Macro F1: 0.63
# Epoch 21, Train Loss: 0.23, Train Acc: 0.93, Train Micro F1: 0.93, Train Macro F1: 0.93
# Epoch 21, Val Loss: 0.98, Val Acc: 0.71, Val Micro F1: 0.71, Val Macro F1: 0.71
# Test Loss: 1.17, Test Acc: 0.64, Test Micro F1: 0.64, Test Macro F1: 0.64
# Epoch 22, Train Loss: 0.28, Train Acc: 0.91, Train Micro F1: 0.91, Train Macro F1: 0.91
# Epoch 22, Val Loss: 1.08, Val Acc: 0.68, Val Micro F1: 0.68, Val Macro F1: 0.68
# Test Loss: 1.27, Test Acc: 0.63, Test Micro F1: 0.63, Test Macro F1: 0.62
# Epoch 23, Train Loss: 0.31, Train Acc: 0.90, Train Micro F1: 0.90, Train Macro F1: 0.90
# Epoch 23, Val Loss: 1.05, Val Acc: 0.68, Val Micro F1: 0.68, Val Macro F1: 0.68
# Test Loss: 1.23, Test Acc: 0.62, Test Micro F1: 0.62, Test Macro F1: 0.62
# Epoch 24, Train Loss: 0.33, Train Acc: 0.89, Train Micro F1: 0.89, Train Macro F1: 0.89
# Epoch 24, Val Loss: 1.02, Val Acc: 0.70, Val Micro F1: 0.70, Val Macro F1: 0.70
# Test Loss: 1.20, Test Acc: 0.65, Test Micro F1: 0.65, Test Macro F1: 0.64
# Epoch 25, Train Loss: 0.18, Train Acc: 0.95, Train Micro F1: 0.95, Train Macro F1: 0.95
# Epoch 25, Val Loss: 0.91, Val Acc: 0.73, Val Micro F1: 0.73, Val Macro F1: 0.73
# Test Loss: 1.10, Test Acc: 0.66, Test Micro F1: 0.66, Test Macro F1: 0.66
# Epoch 26, Train Loss: 0.12, Train Acc: 0.98, Train Micro F1: 0.98, Train Macro F1: 0.98
# Epoch 26, Val Loss: 1.21, Val Acc: 0.68, Val Micro F1: 0.68, Val Macro F1: 0.68
# Test Loss: 1.44, Test Acc: 0.61, Test Micro F1: 0.61, Test Macro F1: 0.61
# Epoch 27, Train Loss: 0.08, Train Acc: 0.99, Train Micro F1: 0.99, Train Macro F1: 0.99
# Epoch 27, Val Loss: 0.99, Val Acc: 0.72, Val Micro F1: 0.72, Val Macro F1: 0.73
# Test Loss: 1.20, Test Acc: 0.66, Test Micro F1: 0.66, Test Macro F1: 0.66
# Epoch 28, Train Loss: 0.06, Train Acc: 0.99, Train Micro F1: 0.99, Train Macro F1: 0.99
# Epoch 28, Val Loss: 0.97, Val Acc: 0.73, Val Micro F1: 0.73, Val Macro F1: 0.73
# Test Loss: 1.15, Test Acc: 0.67, Test Micro F1: 0.67, Test Macro F1: 0.67
# Epoch 29, Train Loss: 0.22, Train Acc: 0.93, Train Micro F1: 0.93, Train Macro F1: 0.93
# Epoch 29, Val Loss: 1.56, Val Acc: 0.60, Val Micro F1: 0.60, Val Macro F1: 0.59
# Test Loss: 1.76, Test Acc: 0.55, Test Micro F1: 0.55, Test Macro F1: 0.54
# Epoch 30, Train Loss: 0.38, Train Acc: 0.87, Train Micro F1: 0.87, Train Macro F1: 0.87
# Epoch 30, Val Loss: 1.15, Val Acc: 0.66, Val Micro F1: 0.66, Val Macro F1: 0.65
# Test Loss: 1.31, Test Acc: 0.61, Test Micro F1: 0.61, Test Macro F1: 0.60
# Epoch 31, Train Loss: 0.27, Train Acc: 0.91, Train Micro F1: 0.91, Train Macro F1: 0.91
# Epoch 31, Val Loss: 0.94, Val Acc: 0.72, Val Micro F1: 0.72, Val Macro F1: 0.72
# Test Loss: 1.11, Test Acc: 0.66, Test Micro F1: 0.66, Test Macro F1: 0.66
# Epoch 32, Train Loss: 0.16, Train Acc: 0.96, Train Micro F1: 0.96, Train Macro F1: 0.96
# Epoch 32, Val Loss: 1.18, Val Acc: 0.68, Val Micro F1: 0.68, Val Macro F1: 0.68
# Test Loss: 1.39, Test Acc: 0.62, Test Micro F1: 0.62, Test Macro F1: 0.62
# Epoch 33, Train Loss: 0.18, Train Acc: 0.95, Train Micro F1: 0.95, Train Macro F1: 0.95
# Epoch 33, Val Loss: 1.00, Val Acc: 0.71, Val Micro F1: 0.71, Val Macro F1: 0.71
# Test Loss: 1.18, Test Acc: 0.65, Test Micro F1: 0.65, Test Macro F1: 0.65
# Epoch 34, Train Loss: 0.12, Train Acc: 0.97, Train Micro F1: 0.97, Train Macro F1: 0.97
# Epoch 34, Val Loss: 1.14, Val Acc: 0.69, Val Micro F1: 0.69, Val Macro F1: 0.68
# Test Loss: 1.33, Test Acc: 0.62, Test Micro F1: 0.62, Test Macro F1: 0.62
# Epoch 35, Train Loss: 0.07, Train Acc: 0.99, Train Micro F1: 0.99, Train Macro F1: 0.99
# Epoch 35, Val Loss: 1.01, Val Acc: 0.72, Val Micro F1: 0.72, Val Macro F1: 0.72
# Test Loss: 1.21, Test Acc: 0.65, Test Micro F1: 0.65, Test Macro F1: 0.65
# Early stopping!

# %%
# Load the best model
model.load_state_dict(torch.load('./model_best.pth'))
# Out:
# <All keys matched successfully>

# %%
# accuracy plot
plt.plot(range(len(train_accs)), train_accs, label='Train')
plt.plot(range(len(val_accs)), val_accs, label='Validation')
plt.plot(range(len(test_accs)), test_accs, label='Test')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("Q1_acc" )

# %%
# Plot the accuracy and loss curves
#plt.figure(figsize=(15,5))
#plt.subplot(1,2,1)
# plt.plot(range(len(train_accs)), train_accs, label='Train')
# plt.plot(range(len(val_accs)), val_accs, label='Validation')
# plt.plot(range(len(test_accs)), test_accs, label='Test')
# plt.title('Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.subplot(1,2,2)
plt.plot(range(len(train_losses)), train_losses, label='Train')
plt.plot(range(len(val_losses)), val_losses, label='Validation')
plt.plot(range(len(test_losses)), test_losses, label='Test')
#plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
#plt.show()
plt.savefig("Q1_loss" )

# %%
# Plot the micro and macro F1 curves
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(range(len(train_micro_f1s)), train_micro_f1s, label='Train')
plt.plot(range(len(val_micro_f1s)), val_micro_f1s, label='Validation')
plt.plot(range(len(test_micro_f1s)), test_micro_f1s, label='Test')
#plt.title('Micro F1')
plt.xlabel('Epoch')
plt.ylabel('Micro F1')
plt.legend()
plt.subplot(1,2,2)
plt.plot(range(len(train_macro_f1s)), train_macro_f1s, label='Train')
plt.plot(range(len(val_macro_f1s)), val_macro_f1s, label='Validation')
plt.plot(range(len(test_macro_f1s)), test_macro_f1s, label='Test')
#plt.title('Macro F1')
plt.xlabel('Epoch')
plt.ylabel('Macro F1')
plt.legend()
#plt.show()
plt.savefig("Q1_micro_macro")

# %%
# Print the confusion matrix
conf_matrix = confusion_matrix(test_targets, test_preds)
print(conf_matrix)
# Out:
# [[771  60  55  21   9   4   6   4  31  39]
#  [  7 919   3   9   0   1   2   2   9  48]
#  [ 98  23 586  73  56  57  60  20  11  16]
#  [ 46  36  86 510  44 139  72  26  13  28]
#  [ 39  19 113  81 558  25  76  75  12   2]
#  [ 18  25 100 214  40 502  35  44   7  15]
#  [ 19  19  81  85  37  22 723   2   9   3]
#  [ 39  28  47  60  79  73  11 618   5  40]
#  [114  95  11  28   6   8   8   2 693  35]
#  [ 40 223   9  20   5   7   9   4  17 666]]

# %%
# Print the classification report
class_report = classification_report(test_targets, test_preds)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.77      0.70      1000
#            1       0.64      0.92      0.75      1000
#            2       0.54      0.59      0.56      1000
#            3       0.46      0.51      0.49      1000
#            4       0.67      0.56      0.61      1000
#            5       0.60      0.50      0.55      1000
#            6       0.72      0.72      0.72      1000
#            7       0.78      0.62      0.69      1000
#            8       0.86      0.69      0.77      1000
#            9       0.75      0.67      0.70      1000
#
#     accuracy                           0.65     10000
#    macro avg       0.67      0.65      0.65     10000
# weighted avg       0.67      0.65      0.65     10000
